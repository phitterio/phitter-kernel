# %%
import sys

sys.path.append("../../../")
import phitter

# %%
def get_data(path: str) -> list[float | int]:
    sample_distribution_file = open(path, "r")
    data = [float(x.replace(",", ".")) for x in sample_distribution_file.read().splitlines()]
    sample_distribution_file.close()
    return data

# %%
path = "../../../datasets_test/continuous/data.txt"
data = get_data(path)

# %%
phitter_cont = phitter.PHITTER(data)
phitter_cont.fit(n_workers=4)

# %%
phitter_cont.best_distribution
# Out:
# {'id': 'loggamma',
#  'parameters': {'c': 7.811180529811271,
#   'mu': 753.4978134786609,
#   'sigma': 65.34574397876038}}

# %%
phitter_cont.df_not_rejected_distributions
# Out:
#            distribution       sse  \
#
# 0              loggamma  0.000002
# 1            johnson_sb  0.000002
# 2            weibull_3p  0.000002
# 3               burr_4p  0.000005
# 4                  burr  0.000005
# 5                  beta  0.000002
# 6              dagum_4p  0.000012
# 7  generalized_gamma_4p  0.000012
# 8        loglogistic_3p  0.000018
#
#                                           parameters     chi_square  \
#                                                      test_statistic
# 0                  c: 7.811, mu: 753.5, sigma: 65.35      14.698834
# 1  xi: -161.3, lambda: 1214, gamma: -11.04, delta...      15.512431
# 2              alpha: 5.958, loc: 759.7, beta: 133.5      19.491335
# 3          A: 904.5, B: 51.64, C: 2.506, loc: 0.8461      19.371923
# 4                       A: 904.5, B: 51.64, C: 2.506      21.655528
# 5         alpha: 42.7, beta: 10.01, A: 518, B: 969.2      28.406801
# 6         a: 73.81, b: 896.2, p: 0.7127, loc: -5.087      34.202976
# 7           a: 29.14, d: 73.17, p: 1.694, loc: 616.2     144.558547
# 8             loc: -2.662, alpha: 886.9, beta: 64.48      58.479681
#
#                                         kolmogorov_smirnov                 \
#   critical_value       p_value rejected     test_statistic critical_value
# 0      22.362032  3.265293e-01    False           0.011286       0.029157
# 1      21.026070  2.146014e-01    False           0.011427       0.029157
# 2      22.362032  1.086397e-01    False           0.009393       0.029157
# 3      21.026070  7.993948e-02    False           0.018166       0.029157
# 4      22.362032  6.093440e-02    False           0.024744       0.029157
# 5      21.026070  4.821604e-03     True           0.010411       0.029157
# 6      21.026070  6.265685e-04     True           0.024181       0.029157
# 7      21.026070  0.000000e+00     True           0.027315       0.029157
# 8      22.362032  9.808328e-08     True           0.025712       0.029157
#
#                      anderson_darling
#     p_value rejected   test_statistic critical_value   p_value rejected
# 0  0.943310    False         0.212963       2.492327  0.986457    False
# 1  0.937625    False         0.232830       2.492327  0.978719    False
# 2  0.990304    False         0.298723       2.492327  0.939109    False
# 3  0.469215    False         0.712676       2.492327  0.548320    False
# 4  0.139982    False         1.857483       2.492327  0.110170    False
# 5  0.971557    False         0.378062       2.492327  0.870179    False
# 6  0.157686    False         2.226240       2.492327  0.069219    False
# 7  0.078431    False         5.411559       2.492327  0.001826     True
# 8  0.113305    False         4.751539       2.492327  0.003771     True

# %%
phitter_cont.df_sorted_distributions_sse.head(10)
# Out:
#            distribution passed       sse  \
#
# 0              loggamma      ✅  0.000002
# 1            johnson_sb      ✅  0.000002
# 2            weibull_3p      ✅  0.000002
# 3               burr_4p      ✅  0.000005
# 4                  burr      ✅  0.000005
# 5                  beta      ✅  0.000002
# 6              dagum_4p      ✅  0.000012
# 7  generalized_gamma_4p      ✅  0.000012
# 8        loglogistic_3p      ✅  0.000018
# 9    generalized_normal      ❌  0.000012
#
#                                           parameters     chi_square  \
#                                                      test_statistic
# 0                  c: 7.811, mu: 753.5, sigma: 65.35      14.698834
# 1  xi: -161.3, lambda: 1214, gamma: -11.04, delta...      15.512431
# 2              alpha: 5.958, loc: 759.7, beta: 133.5      19.491335
# 3          A: 904.5, B: 51.64, C: 2.506, loc: 0.8461      19.371923
# 4                       A: 904.5, B: 51.64, C: 2.506      21.655528
# 5         alpha: 42.7, beta: 10.01, A: 518, B: 969.2      28.406801
# 6         a: 73.81, b: 896.2, p: 0.7127, loc: -5.087      34.202976
# 7           a: 29.14, d: 73.17, p: 1.694, loc: 616.2     144.558547
# 8             loc: -2.662, alpha: 886.9, beta: 64.48      58.479681
# 9                  beta: 1.879, mu: 883.7, alpha: 33      52.963474
#
#                                         kolmogorov_smirnov                 \
#   critical_value       p_value rejected     test_statistic critical_value
# 0      22.362032  3.265293e-01    False           0.011286       0.029157
# 1      21.026070  2.146014e-01    False           0.011427       0.029157
# 2      22.362032  1.086397e-01    False           0.009393       0.029157
# 3      21.026070  7.993948e-02    False           0.018166       0.029157
# 4      22.362032  6.093440e-02    False           0.024744       0.029157
# 5      21.026070  4.821604e-03     True           0.010411       0.029157
# 6      21.026070  6.265685e-04     True           0.024181       0.029157
# 7      21.026070  0.000000e+00     True           0.027315       0.029157
# 8      22.362032  9.808328e-08     True           0.025712       0.029157
# 9      22.362032  9.169967e-07     True           0.031006       0.029157
#
#                      anderson_darling
#     p_value rejected   test_statistic critical_value   p_value rejected
# 0  0.943310    False         0.212963       2.492327  0.986457    False
# 1  0.937625    False         0.232830       2.492327  0.978719    False
# 2  0.990304    False         0.298723       2.492327  0.939109    False
# 3  0.469215    False         0.712676       2.492327  0.548320    False
# 4  0.139982    False         1.857483       2.492327  0.110170    False
# 5  0.971557    False         0.378062       2.492327  0.870179    False
# 6  0.157686    False         2.226240       2.492327  0.069219    False
# 7  0.078431    False         5.411559       2.492327  0.001826     True
# 8  0.113305    False         4.751539       2.492327  0.003771     True
# 9  0.030893     True         3.566837       2.492327  0.014240     True
