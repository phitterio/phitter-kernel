# %%
import sys

sys.path.append("../../../../")
import phitter

# %%
data = phitter.continuous.BETA(init_parameters_examples=True).sample(10000)

# %%
phitter_cont = phitter.PHITTER(data)
phitter_cont.fit(n_workers=4)

# %%
phitter_cont.plot_histogram(plot_engine="matplotlib")

# %%
phitter_cont.plot_histogram(plot_engine="matplotlib")

# %%
phitter_cont.plot_histogram_distributions(plot_engine="matplotlib")

# %%
phitter_cont.plot_distribution("beta", plot_engine="matplotlib")

# %%
phitter_cont.plot_ecdf(plot_engine="matplotlib")

# %%
phitter_cont.plot_ecdf_distribution("beta", plot_engine="matplotlib")

# %%
phitter_cont.qq_plot("beta", plot_engine="matplotlib")

# %%
phitter_cont.qq_plot_regression("beta", plot_engine="matplotlib")
