# %%
import sys

sys.path.append("../../../../")
import phitter

# %%
data = phitter.continuous.Beta(init_parameters_examples=True).sample(10000)

# %%
phi = phitter.Phitter(data=data)
phi.fit(n_workers=4)

# %%
phi.plot_histogram(plot_engine="matplotlib")

# %%
phi.plot_histogram(plot_engine="matplotlib")

# %%
phi.plot_histogram_distributions(plot_engine="matplotlib")

# %%
phi.plot_distribution("beta", plot_engine="matplotlib")

# %%
phi.plot_ecdf(plot_engine="matplotlib")

# %%
phi.plot_ecdf_distribution("beta", plot_engine="matplotlib")

# %%
phi.qq_plot("beta", plot_engine="matplotlib")

# %%
phi.qq_plot_regression("beta", plot_engine="matplotlib")
