# %%
import numpy

# %%
import sys

sys.path.append("../../../")
import phitter

# %%
def get_data(path: str) -> list[float | int]:
    sample_distribution_file = open(path, "r")
    data = [float(x.replace(",", ".")) for x in sample_distribution_file.read().splitlines()]
    sample_distribution_file.close()
    return data

# %%
for id_distribution, distribution_class in phitter.continuous.CONTINUOUS_DISTRIBUTIONS.items():
    data = get_data(f"../../../distributions_samples/continuous_distributions_sample/sample_{id_distribution}.txt")
    continuous_measures = phitter.continuous.ContinuousMeasures(data)
    distribution = distribution_class(continuous_measures=continuous_measures)

    print(f"{distribution.name.upper()} DISTRIBUTION")
    print(f"Parameters: {distribution.parameters}")
    print(f"CDF: {distribution.cdf(continuous_measures.mean)} {distribution.cdf(numpy.array([continuous_measures.mean, continuous_measures.mean]))}")
    print(f"PDF: {distribution.pdf(continuous_measures.mean)} {distribution.pdf(numpy.array([continuous_measures.mean, continuous_measures.mean]))}")
    print(f"PPF: {distribution.ppf(0.5)} {distribution.ppf(numpy.array([0.5, 0.5]))} - V: {distribution.cdf(distribution.ppf(0.5))}")
    print(f"SAMPLE: {distribution.sample(5)}")
    print(f"SAMPLEX: {distribution_class(init_parameters_examples=True).sample(3)}")
    print(f"\nSTATS")
    print(f"mean: {distribution.mean} - {continuous_measures.mean}")
    print(f"variance: {distribution.variance} - {continuous_measures.variance}")
    print(f"skewness: {distribution.skewness} - {continuous_measures.skewness}")
    print(f"kurtosis: {distribution.kurtosis} - {continuous_measures.kurtosis}")
    print(f"median: {distribution.median} - {continuous_measures.median}")
    print(f"mode: {distribution.mode} - {continuous_measures.mode}")
    print("\n\n")
# Out:
# ALPHA DISTRIBUTION
# Parameters: {'alpha': 5.462745545103273, 'loc': 9.38212061799186, 'scale': 57.54060776727926}
# CDF: 0.5781184223125094 [0.57811842 0.57811842]
# PDF: 0.1885417349404305 [0.18854173 0.18854173]
# PPF: 19.91539678521096 [19.91539679 19.91539679] - V: 0.5000000000000002
# SAMPLE: [19.13845905 19.128365   18.65217012 22.80357609 23.1807646 ]
# SAMPLEX: [19.59297601 20.51267256 20.27048479]
#
# STATS
# mean: 20.31187048011524 - 20.30963428847081
# variance: 5.176932542252066 - 5.05349975057239
# skewness: 1.6941898859847813 - 1.3864507896443206
# kurtosis: 12.097388506764505 - 6.761335065059094
# median: 19.91539678521096 - 19.89347807
# mode: 19.290702484344784 - 19.424597812751276
#
#
#
# ARCSINE DISTRIBUTION
# Parameters: {'a': 77.99902392999999, 'b': 89.00098277000001}
# CDF: 0.49179359380093335 [0.49179359 0.49179359]
# PDF: 0.0578834561297963 [0.05788346 0.05788346]
# PPF: 83.50000335 [83.50000335 83.50000335] - V: 0.5000000000000001
# SAMPLE: [78.03029583 87.72706114 87.91092267 78.22984833 88.71529275]
# SAMPLEX: [88.33744279 84.83522067 86.62945239]
#
# STATS
# mean: 83.50000335 - 83.35819728978683
# variance: 15.130387289631816 - 14.880130010016998
# skewness: 6.280369834735096e-16 - 0.0517788328440472
# kurtosis: 1.499999999999997 - 1.5225847298196082
# median: 83.50000335 - 83.286979685
# mode: None - 78.68649000822381
#
#
#
# ARGUS DISTRIBUTION
# Parameters: {'chi': 0.7017971010482332, 'loc': 9.992017975286416, 'scale': 3.0093938140615064}
# CDF: 0.4658488475355139 [0.46584885 0.46584885]
# PDF: 0.47455738551636495 [0.47455739 0.47455739]
# PPF: 11.879682275000944 [11.87968228 11.87968228] - V: 0.5000000000000001
# SAMPLE: [12.32140639 12.03858857 12.8228727  11.58682295 11.98228796]
# SAMPLEX: [106.12596879 104.59945722 105.9288473 ]
#
# STATS
# mean: 11.808531306494064 - 11.808531306494999
# variance: 0.4773607170416416 - 0.47736071706250155
# skewness: -0.3540080716207409 - -0.3672482872960705
# kurtosis: 2.244171778815248 - 2.2556370649906876
# median: 11.879682275000944 - 11.879682275
# mode: 12.245366351532429 - 12.243123568210821
#
#
#
# BETA DISTRIBUTION
# Parameters: {'alpha': 45.83246778284843, 'beta': 10.337834518530881, 'A': 499.0939442805805, 'B': 970.2639535360801}
# CDF: 0.47098701675606114 [0.47098702 0.47098702]
# PDF: 0.016238507415463253 [0.01623851 0.01623851]
# PPF: 885.32173452699 [885.32173453 885.32173453] - V: 0.4999999999999991
# SAMPLE: [892.69656501 874.55275579 904.67425409 881.31070848 892.54819603]
# SAMPLEX: [922.94281073 893.74801676 884.93574427]
#
# STATS
# mean: 883.5477104999729 - 883.5477189089899
# variance: 583.1416817053147 - 583.1414232036951
# skewness: -0.4239115051392973 - -0.36949274911922364
# kurtosis: 3.1635937073098255 - 3.2095609906846714
# median: 885.32173452699 - 885.5576721
# mode: 889.0440343256515 - 888.6555336058005
#
#
#
# BETA_PRIME DISTRIBUTION
# Parameters: {'alpha': 101.78581870980618, 'beta': 54.83167020247322}
# CDF: 0.5369818806457101 [0.53698188 0.53698188]
# PDF: 1.2496797015894983 [1.2496797 1.2496797]
# PPF: 1.8615604855157772 [1.86156049 1.86156049] - V: 0.49999999999999656
# SAMPLE: [2.05142012 2.06264709 1.49805539 1.87724376 1.90112752]
# SAMPLEX: [1.62712976 1.83911817 1.55312105]
#
# STATS
# mean: 1.8908166573128817 - 1.8908166612228916
# variance: 0.10346075124854437 - 0.10346070783536444
# skewness: 0.5736186287510419 - 0.5143614408165199
# kurtosis: 3.621303790606237 - 3.5924585963025706
# median: 1.8615604855157772 - 1.877312653
# mode: 1.8051729125119669 - 1.9080080279603961
#
#
#
# BETA_PRIME_4P DISTRIBUTION
# Parameters: {'alpha': 34.58286227984377, 'beta': 9.964520079048803, 'loc': 100.57083285668593, 'scale': 3.825034002256473}
# CDF: 0.5898080429340402 [0.58980804 0.58980804]
# PDF: 0.07123295596488148 [0.07123296 0.07123296]
# PPF: 114.17016035495703 [114.17016035 114.17016035] - V: 0.5000000000000003
# SAMPLE: [111.20411295 111.48361627 120.41652058 108.46743183 119.37678861]
# SAMPLEX: [118.64454506 113.92549458 106.09747396]
#
# STATS
# mean: 115.32685135508952 - 115.34993741992585
# variance: 34.42547092584288 - 34.42801524281049
# skewness: 1.6316473346480358 - 1.643887412396341
# kurtosis: 8.668885418473367 - 8.08541160375172
# median: 114.17016035495703 - 114.11929695
# mode: 112.28640172676843 - 112.31557298937894
#
#
#
# BRADFORD DISTRIBUTION
# Parameters: {'c': 4.234436911501597, 'min': 19.999243399999997, 'max': 50.00063537}
# CDF: 0.5674595593467946 [0.56745956 0.56745956]
# PDF: 0.03333178677548232 [0.03333179 0.03333179]
# PPF: 29.1240618791272 [29.12406188 29.12406188] - V: 0.5
# SAMPLE: [39.87470573 25.69808444 26.92966753 27.48856106 40.51323391]
# SAMPLEX: [28.50134441 21.9190796  21.41007407]
#
# STATS
# mean: 31.03903721109326 - 31.039037209068574
# variance: 71.79091540413094 - 72.13896868726417
# skewness: 0.5633042270951019 - 0.5554198010384922
# kurtosis: 2.147935443949101 - 2.141931595800687
# median: 29.1240618791272 - 29.121159040000002
# mode: 19.999243399999997 - 22.703458938050805
#
#
#
# BURR DISTRIBUTION
# Parameters: {'A': 1.9775513460024314, 'B': 10.772168961602365, 'C': 0.44538996416029086}
# CDF: 0.6200097685108298 [0.62000977 0.62000977]
# PDF: 0.6752464652246202 [0.67524647 0.67524647]
# PPF: 2.2352206118707265 [2.23522061 2.23522061] - V: 0.5000000000000002
# SAMPLE: [2.36204394 2.5460679  2.09379852 2.09294617 2.77998564]
# SAMPLEX: [0.8435117  0.77417428 0.75860988]
#
# STATS
# mean: 2.39797655989127 - 2.3924347343670065
# variance: 0.5643529689871292 - 0.5351015645784781
# skewness: 3.8361746479095253 - 2.916246166793788
# kurtosis: 65.05109084099871 - 20.068014721960456
# median: 2.2352206118707265 - 2.229214594
# mode: 2.075750757527028 - 2.092902343328233
#
#
#
# BURR_4P DISTRIBUTION
# Parameters: {'A': 108.45506888282289, 'B': 114.40653535544025, 'C': 1.3102772552120885, 'loc': -0.8007729816684774}
# CDF: 0.4885163183141247 [0.48851632 0.48851632]
# PDF: 0.28414597335947256 [0.28414597 0.28414597]
# PPF: 107.31297903969752 [107.31297904 107.31297904] - V: 0.5000000000000009
# SAMPLE: [107.54700954 108.99818991 105.19021009 108.12577746 104.68936794]
# SAMPLEX: [105.44696256 108.62651847 107.34535717]
#
# STATS
# mean: 107.2686421277796 - 107.27261441070436
# variance: 2.459965625334007 - 2.378776649221853
# skewness: -0.2003913702426687 - -0.056238828969181004
# kurtosis: 4.084676638662979 - 3.304257451184863
# median: 107.31297903969752 - 107.31811875
# mode: 107.38382747727009 - 107.32505061131113
#
#
#
# CAUCHY DISTRIBUTION
# Parameters: {'x0': 10.759792996534902, 'gamma': 19.22030310470703}
# CDF: 0.9569654150630034 [0.95696542 0.95696542]
# PDF: 0.0003008688414352775 [0.00030087 0.00030087]
# PPF: 10.759792996534902 [10.759793 10.759793] - V: 0.5
# SAMPLE: [ -2.19526236  25.14801628 -18.69575085  -6.45190908 235.39260566]
# SAMPLEX: [ 47.19688398 -49.48278258  84.95561075]
#
# STATS
# mean: None - 152.0575759044903
# variance: None - 49982394.03401568
# skewness: None - 46.154846361387385
# kurtosis: None - 2142.760612768349
# median: 10.759792996534902 - 10.873164280000001
# mode: 10.759792996534902 - 24.38482806180582
#
#
#
# CHI_SQUARE DISTRIBUTION
# Parameters: {'df': 7}
# CDF: 0.5705556940333787 [0.57055569 0.57055569]
# PDF: 0.10420033221553353 [0.10420033 0.10420033]
# PPF: 6.345811195521515 [6.3458112 6.3458112] - V: 0.5
# SAMPLE: [13.80564938  8.31143989 13.28534651  9.03093424  6.51838172]
# SAMPLEX: [5.11606651 8.99749367 7.48955041]
#
# STATS
# mean: 7 - 6.994580951601483
# variance: 14 - 14.044635753085412
# skewness: 1.0690449676496976 - 1.0439923454822189
# kurtosis: 4.714285714285714 - 4.52846962724633
# median: 6.345811195521515 - 6.390949411499999
# mode: 5 - 4.722570044189719
#
#
#
# CHI_SQUARE_3P DISTRIBUTION
# Parameters: {'df': 5.427666780269736, 'loc': 9.680108790326281, 'scale': 1.9390767884542408}
# CDF: 0.5807485082359263 [0.58074851 0.58074851]
# PDF: 0.06056418335905264 [0.06056418 0.06056418]
# PPF: 18.944111894999995 [18.94411189 18.94411189] - V: 0.49999999999999994
# SAMPLE: [26.05962598 17.87904877 13.13682097 23.39318495 21.27836949]
# SAMPLEX: [24.12638147 14.76247912 17.83248576]
#
# STATS
# mean: 20.20477145941149 - 20.204771459411493
# variance: 40.81625817586797 - 40.816258175867965
# skewness: 1.2140551201053449 - 1.1892965717626238
# kurtosis: 5.210894751981005 - 4.922677280334262
# median: 18.944111894999995 - 18.944111895
# mode: 16.326617882503008 - 15.956569099450945
#
#
#
# DAGUM DISTRIBUTION
# Parameters: {'a': 5.084379838794465, 'b': 50.71729648898703, 'p': 2.8443698187871824}
# CDF: 0.605083322097179 [0.60508332 0.60508332]
# PDF: 0.020216795271427276 [0.0202168 0.0202168]
# PPF: 65.33321818913466 [65.33321819 65.33321819] - V: 0.5
# SAMPLE: [31.38609217 69.16862143 53.95000546 79.80831898 75.61797241]
# SAMPLEX: [111.06907169  38.23524033  62.96473155]
#
# STATS
# mean: 70.25128717809493 - 70.07960452432344
# variance: 548.5680908267377 - 522.9339743533989
# skewness: 3.045109424363756 - 2.069749350452403
# kurtosis: 37.16052545430604 - 10.457131259188692
# median: 65.33321818913466 - 64.59603301499999
# mode: 59.29104107064981 - 60.32673728647465
#
#
#
# DAGUM_4P DISTRIBUTION
# Parameters: {'a': 6.528213984110061, 'b': 1.8387936281047281, 'p': 3.2260460610087547, 'loc': 100.13817641008131}
# CDF: 0.5961842415374553 [0.59618424 0.59618424]
# PDF: 0.018137927831221548 [0.01813793 0.01813793]
# PPF: 102.42672202061009 [102.42672202 102.42672202] - V: 0.49999999999999906
# SAMPLE: [103.00572968 102.57118099 102.15606574 101.99340183 101.98182001]
# SAMPLEX: [101.36835022 101.16825636 101.10728198]
#
# STATS
# mean: 102.54203671674527 - 102.54203670078776
# variance: 0.34573092638968106 - 0.34573092752841106
# skewness: 2.25144533391686 - 1.937917824683206
# kurtosis: 17.06051333765231 - 10.037647403743227
# median: 102.42672202061009 - 102.42672205
# mode: 102.27482922594604 - 102.27482921647164
#
#
#
# ERLANG DISTRIBUTION
# Parameters: {'k': 48, 'beta': 5.2084603589612675}
# CDF: 0.5292073131288131 [0.52920731 0.52920731]
# PDF: 0.010992912744366368 [0.01099291 0.01099291]
# PPF: 248.2721035083003 [248.27210351 248.27210351] - V: 0.4999999999999999
# SAMPLE: [228.65523262 263.89174424 225.81672763 299.54333388 196.80579959]
# SAMPLEX: [232.08662499 290.45148924 231.19299712]
#
# STATS
# mean: 250.0060972301399 - 250.91493972391106
# variance: 1302.1468469227839 - 1306.8805170231467
# skewness: 0.2886751345762028 - 0.3406864114780396
# kurtosis: 3.125000000258688 - 3.1221391358324304
# median: 248.2721035083003 - 248.89499165
# mode: 244.79763687117958 - 240.064625850065
#
#
#
# ERLANG_3P DISTRIBUTION
# Parameters: {'k': 54, 'beta': 5.883985314902859, 'loc': 982.3390574483549}
# CDF: 0.5162686047215298 [0.5162686 0.5162686]
# PDF: 0.00921803347101864 [0.00921803 0.00921803]
# PPF: 1298.115102939236 [1298.11510294 1298.11510294] - V: 0.49999999999999983
# SAMPLE: [1328.48832775 1350.92946801 1378.48536502 1248.91123564 1316.46639374]
# SAMPLEX: [1189.85759098 1196.62377071 1283.74554298]
#
# STATS
# mean: 1300.0742644531053 - 1299.8757266367006
# variance: 1869.5492920443503 - 1868.3810984473935
# skewness: 0.2721655269765287 - 0.27225059857711975
# kurtosis: 3.1111111111054255 - 2.969494263494989
# median: 1298.115102939236 - 1297.264582
# mode: 1294.1902791382065 - 1294.5418045623562
#
#
#
# ERROR_FUNCTION DISTRIBUTION
# Parameters: {'h': 9.88829407340195}
# CDF: 0.5108835278548217 [0.51088353 0.51088353]
# PDF: 5.576796346589474 [5.57679635 5.57679635]
# PPF: 0.0 [0. 0.] - V: 0.5
# SAMPLE: [ 0.06898801  0.09609464 -0.07063953  0.00438208 -0.13605239]
# SAMPLEX: [ 0.18173883 -0.05553752 -0.05336903]
#
# STATS
# mean: 0 - 0.0019510892548656174
# variance: 0.005113605931064271 - 0.005113605931064271
# skewness: 0 - -0.03002430616749843
# kurtosis: 3 - 2.980764434798136
# median: 0.0 - 0.0018351819999999999
# mode: 0 - -0.0011271224216421183
#
#
#
# EXPONENTIAL DISTRIBUTION
# Parameters: {'lambda': 0.05021666217128976}
# CDF: 0.6321205588285577 [0.63212056 0.63212056]
# PDF: 0.018473677617069185 [0.01847368 0.01847368]
# PPF: 13.803131283310114 [13.80313128 13.80313128] - V: 0.5
# SAMPLE: [35.17809487  3.60851392 51.07046511  2.25402615 19.07807046]
# SAMPLEX: [14.61067454 14.43440278  8.64046584]
#
# STATS
# mean: 19.913709051170816 - 19.913709051170816
# variance: 396.55580817468245 - 406.28768633708944
# skewness: 2 - 2.0602284740702146
# kurtosis: 9 - 9.460925730476117
# median: 13.803131283310114 - 13.81871893
# mode: 0 - 4.853637154510451
#
#
#
# EXPONENTIAL_2P DISTRIBUTION
# Parameters: {'lambda': 0.09955330206607137, 'loc': 50.00000694}
# CDF: 0.6279519957229074 [0.627952 0.627952]
# PDF: 0.03703860735287641 [0.03703861 0.03703861]
# PPF: 56.96258041747158 [56.96258042 56.96258042] - V: 0.4999999999999999
# SAMPLE: [59.61530672 62.45047304 59.85436356 74.38815958 52.1941669 ]
# SAMPLEX: [ 89.93672542 106.69165822 249.55163073]
#
# STATS
# mean: 60.04487716777327 - 59.9316954803017
# variance: 100.89941789280593 - 100.54380438793787
# skewness: 2 - 1.995401470541671
# kurtosis: 9 - 8.443929963831717
# median: 56.96258041747158 - 56.849398730000004
# mode: 50.00000694 - 52.477343657407744
#
#
#
# F DISTRIBUTION
# Parameters: {'df1': 5.571015542549327, 'df2': 5.192842621187688}
# CDF: 0.6871768928407547 [0.68717689 0.68717689]
# PDF: 0.24499346854938225 [0.24499347 0.24499347]
# PPF: 1.0093624996023873 [1.0093625 1.0093625] - V: 0.49999999999999967
# SAMPLE: [1.59880647 0.34545742 0.82103941 9.41490653 0.35962036]
# SAMPLEX: [1.01698827 2.30309683 1.85140142]
#
# STATS
# mean: 1.626401059271763 - 1.5730915461709916
# variance: 6.976909897404658 - 4.591570217925138
# skewness: -7.851585463179836 - 6.313758086679873
# kurtosis: 25.313933748803034 - 73.56708339453186
# median: 1.0093624996023873 - 0.9883941955
# mode: 0.4627665643744898 - 0.7320689545520552
#
#
#
# FATIGUE_LIFE DISTRIBUTION
# Parameters: {'gamma': 3.0220423970905346, 'loc': 15.000532142725103, 'scale': 4.842627949023088}
# CDF: 0.7387327670517312 [0.73873277 0.73873277]
# PDF: 0.005562828674306227 [0.00556283 0.00556283]
# PPF: 19.84316009174819 [19.84316009 19.84316009] - V: 0.49999999999999994
# SAMPLE: [15.33110696 20.55948395 15.90563147 15.94576595 15.77000192]
# SAMPLEX: [ 41.387996     3.93365281 138.19322276]
#
# STATS
# mean: 41.95639168420374 - 41.89757506483001
# variance: 2659.1473640135623 - 2612.306599336672
# skewness: 3.6769604981529125 - 3.657841022621265
# kurtosis: 22.75806372598052 - 22.702905199069754
# median: 19.84316009174819 - 19.81841397
# mode: None - 17.875319496440643
#
#
#
# FOLDED_NORMAL DISTRIBUTION
# Parameters: {'mu': 100.50878875724395, 'sigma': 59.5806106521685}
# CDF: 0.514736005001805 [0.51473601 0.51473601]
# PDF: 0.0067109481881419955 [0.00671095 0.00671095]
# PPF: 100.56394907848052 [100.56394908 100.56394908] - V: 0.5
# SAMPLE: [143.49960034 136.75569742 117.58481119 101.2466155  144.10229215]
# SAMPLEX: [80.26858002 54.79622212 80.38839942]
#
# STATS
# mean: 102.75831348218443 - 102.75831348218443
# variance: 3092.594793430695 - 3092.5947934306937
# skewness: 0.30743482113058646 - 0.325178618728219
# kurtosis: 2.672499871270544 - 2.5767435921962547
# median: 100.56394907848052 - 99.254987315
# mode: 100.50878875724395 - 96.94891256072808
#
#
#
# FRECHET DISTRIBUTION
# Parameters: {'alpha': 5.1683615950040664, 'loc': 9.208306060340457, 'scale': 20.767193940203455}
# CDF: 0.6247736865961532 [0.62477369 0.62477369]
# PDF: 0.06320548841536631 [0.06320549 0.06320549]
# PPF: 31.501674351482265 [31.50167435 31.50167435] - V: 0.5
# SAMPLE: [45.39659204 35.93544864 29.59638267 31.18850095 39.89351087]
# SAMPLEX: [28.13075582 35.63915599 51.26996051]
#
# STATS
# mean: 33.23572637075711 - 33.238460540479004
# variance: 52.364141216910014 - 52.907835261319285
# skewness: 3.367980646082366 - 3.5348988564230917
# kurtosis: 41.12762239832176 - 37.405836207908855
# median: 31.501674351482265 - 31.428760235
# mode: 29.276805508047538 - 29.80564343271827
#
#
#
# F_4P DISTRIBUTION
# Parameters: {'df1': 41.94394742582194, 'df2': 31.04391582530996, 'loc': 958.7274390151325, 'scale': 165.27674864852685}
# CDF: 0.5745566079338833 [0.57455661 0.57455661]
# PDF: 0.0065397038681252306 [0.0065397 0.0065397]
# PPF: 1124.9394593733875 [1124.93945937 1124.93945937] - V: 0.5000000000000028
# SAMPLE: [1152.19345548 1093.31058481 1083.38473053 1186.34750469 1090.98942388]
# SAMPLEX: [1173.00527795 1031.80045307 1043.18817777]
#
# STATS
# mean: 1135.3853491876505 - 1135.8369327451342
# variance: 3906.082402071503 - 3906.066991834918
# skewness: 2.6923520842074104e-07 - 1.3306696499716495
# kurtosis: 7.946253730249221e-09 - 6.117100799874921
# median: 1124.9394593733875 - 1124.076318
# mode: 1106.5968802689183 - 1107.0069703867387
#
#
#
# GAMMA DISTRIBUTION
# Parameters: {'alpha': 1.9571525624910866, 'beta': 10.3731647229324}
# CDF: 0.5950100656796262 [0.59501007 0.59501007]
# PDF: 0.026353929424225205 [0.02635393 0.02635393]
# PPF: 16.968359583121963 [16.96835958 16.96835958] - V: 0.49999999999999994
# SAMPLE: [34.88064331 16.42415935 11.25670749 24.07009953  7.89921879]
# SAMPLEX: [18.52754901 11.94822017  5.54579228]
#
# STATS
# mean: 20.30186591862929 - 20.30186591862929
# variance: 210.59459935682872 - 210.59459935682892
# skewness: 1.429610256480555 - 1.4037420247103363
# kurtosis: 6.065678228151577 - 5.820315815461966
# median: 16.968359583121963 - 17.174645995
# mode: 9.928701195696888 - 10.429678071230422
#
#
#
# GAMMA_3P DISTRIBUTION
# Parameters: {'alpha': 22.45253885238332, 'loc': 102.36869087852193, 'beta': 2.134435917743617}
# CDF: 0.5280706699859753 [0.52807067 0.52807067]
# PDF: 0.03929908378251095 [0.03929908 0.03929908]
# PPF: 149.58262607043383 [149.58262607 149.58262607] - V: 0.5000000000000006
# SAMPLE: [152.7395039  145.18662144 148.75203559 171.80882776 156.09404691]
# SAMPLEX: [143.88411727 140.44425516 145.69475996]
#
# STATS
# mean: 150.29219624958293 - 150.29219624958293
# variance: 102.28965116817153 - 102.28965116817176
# skewness: 0.4220824233875825 - 0.4220824233875248
# kurtosis: 3.2672303581989097 - 3.2645719022845845
# median: 149.58262607043383 - 149.33796055
# mode: 148.1577603318393 - 146.6511360909091
#
#
#
# GENERALIZED_EXTREME_VALUE DISTRIBUTION
# Parameters: {'xi': 0.2065399869552406, 'mu': 10.074621187769619, 'sigma': 1.9939505471009862}
# CDF: 0.6283453522244865 [0.62834535 0.62834535]
# PDF: 0.1249900553651496 [0.12499006 0.12499006]
# PPF: 10.833802163222325 [10.83380216 10.83380216] - V: 0.5000000000000002
# SAMPLE: [ 9.84456818  9.43399351 10.6333039   7.9506371  10.83441956]
# SAMPLEX: [ 9.57038252 10.07945314 10.6727183 ]
#
# STATS
# mean: 11.731822887759584 - 11.730463970072753
# variance: 13.719252385717047 - 13.168139526895617
# skewness: 3.7185005813597183 - 2.5984851436475838
# kurtosis: 57.360948202636 - 14.014990089615965
# median: 10.833802163222325 - 10.838461365
# mode: 9.707409633176697 - 10.110495135674567
#
#
#
# GENERALIZED_GAMMA DISTRIBUTION
# Parameters: {'a': 10.327607208607061, 'd': 128.58560687249422, 'p': 24.067383364788753}
# CDF: 0.4744471264915498 [0.47444713 0.47444713]
# PDF: 0.4744471264915498 [0.47444713 0.47444713]
# PPF: 11.043075623346036 [11.04307562 11.04307562] - V: 0.5000000000000014
# SAMPLE: [11.14384927 10.75041507 11.09458595 11.08807105 11.0405192 ]
# SAMPLEX: [10.39572442 10.85535339 10.65617206]
#
# STATS
# mean: 11.02996103874426 - 11.029961038744208
# variance: 0.042862049888981346 - 0.0428620498823726
# skewness: -0.3904579530477265 - -0.39045798274241467
# kurtosis: 3.30009359601848 - 3.174184923239094
# median: 11.043075623346036 - 11.04321047
# mode: 11.068720187661235 - 11.066675847040704
#
#
#
# GENERALIZED_GAMMA_4P DISTRIBUTION
# Parameters: {'a': 31.72425194884897, 'd': 6.493908650897469, 'p': 12.551837638817169, 'loc': 98.19315295931293}
# CDF: 0.43841344340375094 [0.43841344 0.43841344]
# PDF: 0.09114012741862312 [0.09114013 0.09114013]
# PPF: 126.53092475080953 [126.53092475 126.53092475] - V: 0.5000000000000007
# SAMPLE: [118.64697797 128.87813212 127.92819266 122.5971991  126.06916734]
# SAMPLEX: [30.15181421 31.10686885 30.67506642]
#
# STATS
# mean: 125.878472193291 - 125.87847219329099
# variance: 18.172819585220964 - 18.17281958522077
# skewness: -0.808868239484178 - -0.8088682394840466
# kurtosis: 3.716524212912224 - 3.7165242129096248
# median: 126.53092475080953 - 126.506294865
# mode: 127.89639627241297 - 127.73932057716071
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 for id_distribution, distribution_class in phitter.continuous.CONTINUOUS_DISTRIBUTIONS.items():
#       2     data = get_data(f"../../../samples/continuous_distributions_sample/sample_{id_distribution}.txt")
# ----> 3     continuous_measures = phitter.continuous.ContinuousMeasures(data)
#       4     distribution = distribution_class(continuous_measures=continuous_measures)
#       6     print(f"{distribution.name.upper()} DISTRIBUTION")
#
# File d:\SJHM\phitter\dev\phitter-kernel\tests\phitter_local\distributions\../../..\phitter\continuous\continuous_measures\continuous_measures.py:27, in ContinuousMeasures.__init__(self, data, num_bins, confidence_level, subsample_size, subsample_estimation_size)
#      25 self.kurtosis = scipy.stats.kurtosis(self.data, fisher=False, bias=False)
#      26 self.median = numpy.median(self.data)
# ---> 27 self.mode = self.calculate_mode()
#      28 self.num_bins = num_bins if num_bins != None else len(numpy.histogram_bin_edges(self.data, bins="doane"))
#      29 self.absolutes_frequencies, self.bin_edges = numpy.histogram(self.data, self.num_bins)
#
# File d:\SJHM\phitter\dev\phitter-kernel\tests\phitter_local\distributions\../../..\phitter\continuous\continuous_measures\continuous_measures.py:53, in ContinuousMeasures.calculate_mode(self)
#      51 distribution = scipy.stats.gaussian_kde(self.data)
#      52 x = numpy.linspace(self.min, self.max, 10000)
# ---> 53 y = distribution.pdf(x)
#      54 return x[numpy.argmax(y)]
#
# File c:\Users\sejohermo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_kde.py:613, in gaussian_kde.pdf(self, x)
#     603 def pdf(self, x):
#     604     """
#     605     Evaluate the estimated pdf on a provided set of points.
#     606
#    (...)
#     611
#     612     """
# --> 613     return self.evaluate(x)
#
# File c:\Users\sejohermo\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_kde.py:268, in gaussian_kde.evaluate(self, points)
#     265         raise ValueError(msg)
#     267 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 268 result = gaussian_kernel_estimate[spec](
#     269     self.dataset.T, self.weights[:, None],
#     270     points.T, self.cho_cov, output_dtype)
#     272 return result[:, 0]
#
# KeyboardInterrupt:
