# %%
import numpy
import pandas as pd
import scipy.stats as st
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy
import random
import sys
    import numpy
import numpy
import os
import scipy.stats

# %%
sys.path.append("../continuous")
sys.path.append("../continuous/measurements")
from measurements import MEASUREMENTS_CONTINUOUS
import test_chi_square

# %%
from distributions.alpha import ALPHA
from distributions.arcsine import ARCSINE
from distributions.argus import ARGUS
from distributions.beta import BETA
from distributions.beta_prime import BETA_PRIME
from distributions.beta_prime_4p import BETA_PRIME_4P
from distributions.bradford import BRADFORD
from distributions.burr import BURR
from distributions.burr_4p import BURR_4P
from distributions.cauchy import CAUCHY
from distributions.chi_square import CHI_SQUARE
from distributions.chi_square_3p import CHI_SQUARE_3P
from distributions.dagum import DAGUM
from distributions.dagum_4p import DAGUM_4P
from distributions.erlang import ERLANG
from distributions.erlang_3p import ERLANG_3P
from distributions.error_function import ERROR_FUNCTION
from distributions.exponential import EXPONENTIAL
from distributions.exponential_2p import EXPONENTIAL_2P
from distributions.f import F
from distributions.fatigue_life import FATIGUE_LIFE
from distributions.folded_normal import FOLDED_NORMAL
from distributions.frechet import FRECHET
from distributions.f_4p import F_4P
from distributions.gamma import GAMMA
from distributions.gamma_3p import GAMMA_3P
from distributions.generalized_extreme_value import GENERALIZED_EXTREME_VALUE
from distributions.generalized_gamma import GENERALIZED_GAMMA
from distributions.generalized_gamma_4p import GENERALIZED_GAMMA_4P
from distributions.generalized_logistic import GENERALIZED_LOGISTIC
from distributions.generalized_normal import GENERALIZED_NORMAL
from distributions.generalized_pareto import GENERALIZED_PARETO
from distributions.gibrat import GIBRAT
from distributions.gumbel_left import GUMBEL_LEFT
from distributions.gumbel_right import GUMBEL_RIGHT
from distributions.half_normal import HALF_NORMAL
from distributions.hyperbolic_secant import HYPERBOLIC_SECANT
from distributions.inverse_gamma import INVERSE_GAMMA
from distributions.inverse_gamma_3p import INVERSE_GAMMA_3P
from distributions.inverse_gaussian import INVERSE_GAUSSIAN
from distributions.inverse_gaussian_3p import INVERSE_GAUSSIAN_3P
from distributions.johnson_sb import JOHNSON_SB
from distributions.johnson_su import JOHNSON_SU
from distributions.kumaraswamy import KUMARASWAMY
from distributions.laplace import LAPLACE
from distributions.levy import LEVY
from distributions.loggamma import LOGGAMMA
from distributions.logistic import LOGISTIC
from distributions.loglogistic import LOGLOGISTIC
from distributions.loglogistic_3p import LOGLOGISTIC_3P
from distributions.lognormal import LOGNORMAL
from distributions.maxwell import MAXWELL
from distributions.moyal import MOYAL
from distributions.nakagami import NAKAGAMI
from distributions.non_central_chi_square import NON_CENTRAL_CHI_SQUARE
from distributions.non_central_f import NON_CENTRAL_F
from distributions.non_central_t_student import NON_CENTRAL_T_STUDENT
from distributions.normal import NORMAL
from distributions.pareto_first_kind import PARETO_FIRST_KIND
from distributions.pareto_second_kind import PARETO_SECOND_KIND
from distributions.pert import PERT
from distributions.power_function import POWER_FUNCTION
from distributions.rayleigh import RAYLEIGH
from distributions.reciprocal import RECIPROCAL
from distributions.rice import RICE
from distributions.semicircular import SEMICIRCULAR
from distributions.trapezoidal import TRAPEZOIDAL
from distributions.triangular import TRIANGULAR
from distributions.t_student import T_STUDENT
from distributions.t_student_3p import T_STUDENT_3P
from distributions.uniform import UNIFORM
from distributions.weibull import WEIBULL
from distributions.weibull_3p import WEIBULL_3P

# %%
_all_distributions = [
    ALPHA,
    ARCSINE,
    ARGUS,
    BETA,
    BETA_PRIME,
    BETA_PRIME_4P,
    BRADFORD,
    BURR,
    BURR_4P,
    CAUCHY,
    CHI_SQUARE,
    CHI_SQUARE_3P,
    DAGUM,
    DAGUM_4P,
    ERLANG,
    ERLANG_3P,
    ERROR_FUNCTION,
    EXPONENTIAL,
    EXPONENTIAL_2P,
    F,
    FATIGUE_LIFE,
    FOLDED_NORMAL,
    FRECHET,
    F_4P,
    GAMMA,
    GAMMA_3P,
    GENERALIZED_EXTREME_VALUE,
    GENERALIZED_GAMMA,
    GENERALIZED_GAMMA_4P,
    GENERALIZED_LOGISTIC,
    GENERALIZED_NORMAL,
    GENERALIZED_PARETO,
    GIBRAT,
    GUMBEL_LEFT,
    GUMBEL_RIGHT,
    HALF_NORMAL,
    HYPERBOLIC_SECANT,
    INVERSE_GAMMA,
    INVERSE_GAMMA_3P,
    INVERSE_GAUSSIAN,
    INVERSE_GAUSSIAN_3P,
    JOHNSON_SB,
    JOHNSON_SU,
    KUMARASWAMY,
    LAPLACE,
    LEVY,
    LOGGAMMA,
    LOGISTIC,
    LOGLOGISTIC,
    LOGLOGISTIC_3P,
    LOGNORMAL,
    MAXWELL,
    MOYAL,
    NAKAGAMI,
    NON_CENTRAL_CHI_SQUARE,
    NON_CENTRAL_F,
    NON_CENTRAL_T_STUDENT,
    NORMAL,
    PARETO_FIRST_KIND,
    PARETO_SECOND_KIND,
    PERT,
    POWER_FUNCTION,
    RAYLEIGH,
    RECIPROCAL,
    RICE,
    SEMICIRCULAR,
    TRAPEZOIDAL,
    TRIANGULAR,
    T_STUDENT,
    T_STUDENT_3P,
    UNIFORM,
    WEIBULL,
    WEIBULL_3P,
]

# %%
path = "./data/data_alpha.txt"
sample_distribution_file = open(path, "r")
data = [float(x.replace(",", ".")) for x in sample_distribution_file.read().splitlines()]

# %%
measurements = MEASUREMENTS_CONTINUOUS(data)

# %%
str(measurements).replace("'", "")
# Out:
# '{length: 10000, mean: 20.263554240575, variance: 5.946922625228556, skewness: 2.3227091099604085, kurtosis: 21.290769574206738, median: 19.796450965, mode: 19.098907131884353}'

# %%
## Calculae Histogram
num_bins = measurements.num_bins_doane()
frequencies, bin_edges = numpy.histogram(data, num_bins, density=True)
central_values = [(bin_edges[i] + bin_edges[i + 1]) / 2 for i in range(len(bin_edges) - 1)]

# %%
results = {}

# %%
for distribution_class in _all_distributions:
    try:
        distribution = distribution_class(measurements)

        chi2_test = test_chi_square.test_chi_square_continuous(data, distribution, measurements)
        test_statistic = chi2_test["test_statistic"]
        critical_value = chi2_test["critical_value"]
        p_value = chi2_test["p-value"]
        rejected = chi2_test["rejected"]
        distribution = distribution_class(measurements)
        # if numpy.isnan(test_statistic) == False and test_statistic > 0:
        if test_statistic > 0:
            results[distribution] = p_value
            print(distribution_class.__name__)
            print(chi2_test)
            print(str(chi2_test).replace("'test_statistic'", "testStatistic").replace("'critical_value'", "criticalValue").replace("'p-value'", "pValue").replace("'rejected'", "rejected").replace("True", "true").replace("False", "false"))
            print(str(distribution.get_parameters(measurements)).replace("'", ""))
    except:
        print("XXX")
# Out:
# ALPHA
# {'test_statistic': 42.48702093112486, 'critical_value': 27.58711163827534, 'p-value': 0.000570182816067355, 'rejected': True}
# {testStatistic: 42.48702093112486, criticalValue: 27.58711163827534, pValue: 0.000570182816067355, rejected: true}
# {alpha: 5.048871384930049, loc: 9.842567976704679, scale: 50.33641144372197}
# ARCSINE
# {'test_statistic': 46550.394997147196, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 46550.394997147196, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {a: 15.65330611, b: 65.19363605000001}
# ARGUS
# {'test_statistic': 82110.18091888257, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 82110.18091888257, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {chi: 1.1093727171775313e-06, loc: -14.479974255638577, scale: 79.67487157434493}
# BETA_PRIME
# {'test_statistic': inf, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: inf, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {alpha: 1488.4283894568412, beta: 74.45347078729489}
# BETA_PRIME_4P
# {'test_statistic': 1897.0143030258337, 'critical_value': 26.29622760486423, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 1897.0143030258337, criticalValue: 26.29622760486423, pValue: 0.0, rejected: true}
# {alpha: 65.29455014212002, beta: 12.854444187581084, scale: 1.3418896291615177, loc: 12.859792984439835}
# BRADFORD
# {'test_statistic': 47112.26356334876, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 47112.26356334876, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {c: 46313.22517345912, min: 15.65330611, max: 65.19363605000001}
# BURR
# {'test_statistic': 168.07037104115176, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 168.07037104115176, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {A: 18.61887395575193, B: 28.832961095187862, C: 0.35076921516889276}
# BURR_4P
# {'test_statistic': 140.85089191215047, 'critical_value': 26.29622760486423, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 140.85089191215047, criticalValue: 26.29622760486423, pValue: 0.0, rejected: true}
# {A: 18.61887395575193, B: 28.832961095187862, C: 0.35076921516889276, loc: -0.09818823211425831}
# CAUCHY
# {'test_statistic': 703.3310013777339, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 703.3310013777339, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {x0: 19.65614892104115, gamma: 1.185889866856514}
# CHI_SQUARE
# {'test_statistic': 9762.252797821146, 'critical_value': 30.14352720564616, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 9762.252797821146, criticalValue: 30.14352720564616, pValue: 0.0, rejected: true}
# {df: 20}
# CHI_SQUARE_3P
# {'test_statistic': 17661200983.1539, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 17661200983.1539, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {df: 8.454833596753993, loc: 15.594562136035574, scale: 0.5522271581103115}
# DAGUM
# {'test_statistic': 487.85566496369916, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 487.85566496369916, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {a: 12.02211457859675, b: 15.747989785246709, p: 12.574232996552896}
# EXPONENTIAL
# {'test_statistic': 57970.36226840052, 'critical_value': 30.14352720564616, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 57970.36226840052, criticalValue: 30.14352720564616, pValue: 0.0, rejected: true}
# {lambda: 0.049349684074555714}
# EXPONENTIAL_2P
# {'test_statistic': 3661595953.921611, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 3661595953.921611, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {lambda: 0.6569271411387982, loc: 15.65420611}
# F
# {'test_statistic': inf, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: inf, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {df1: 309.7319771570189, df2: 21.987499644893703}
# FATIGUE_LIFE
# {'test_statistic': 17854937.220064964, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 17854937.220064964, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {gamma: 0.3970564263118137, loc: 14.518857800164337, scale: 5.325216467932494}
# FRECHET
# {'test_statistic': 379895.4439287447, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 379895.4439287447, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {alpha: 16.16469218151791, loc: -8.317838295943933, scale: 27.49033417530576}
# F_4P
# {'test_statistic': 1810.7013412387328, 'critical_value': 26.29622760486423, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 1810.7013412387328, criticalValue: 26.29622760486423, pValue: 0.0, rejected: true}
# {df1: 333.5958855646802, df2: 25.487181059783136, loc: 12.525430187920158, scale: 7.119441677666505}
# GENERALIZED_EXTREME_VALUE
# {'test_statistic': 1188.0984727184896, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 1188.0984727184896, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {xi: 0.061871420666201576, mu: 19.172516714652595, sigma: 1.7006342719722913}
# XXX
# GENERALIZED_LOGISTIC
# {'test_statistic': 1340663.674966576, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 1340663.674966576, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {c: 10183.016935371425, loc: 1.5847411018308386, scale: 1.9015152275577407}
# GENERALIZED_NORMAL
# {'test_statistic': 8660794579.636974, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 8660794579.636974, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {beta: 1.1150960411837714, mu: 19.849370811385732, alpha: 1.9873492577755534}
# GENERALIZED_PARETO
# {'test_statistic': 7092.469767705959, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 7092.469767705959, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {c: 0.1800099562516253, mu: 15.654306109959077, sigma: 4.574632672516721}
# GIBRAT
# {'test_statistic': 4791.48120292652, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 4791.48120292652, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {loc: 15.651100089336857, scale: 4.062431958977626}
# GUMBEL_RIGHT
# {'test_statistic': 1325737.845459289, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 1325737.845459289, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {mu: 19.166040401263636, sigma: 1.9013930252594637}
# HYPERBOLIC_SECANT
# {'test_statistic': 162972836.23697603, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 162972836.23697603, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {mu: 20.263554240575, sigma: 2.438631301617478}
# INVERSE_GAMMA
# {'test_statistic': 3237630.569305126, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 3237630.569305126, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {alpha: 10.980752546770297, beta: 70.54884155373264}
# INVERSE_GAMMA_3P
# {'test_statistic': 845.7294324755601, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 845.7294324755601, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {alpha: 10.980752546770297, beta: 70.54884155373264, loc: 13.189841089051349}
# XXX
# JOHNSON_SB
# {'test_statistic': 53485.05429209974, 'critical_value': 26.29622760486423, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 53485.05429209974, criticalValue: 26.29622760486423, pValue: 0.0, rejected: true}
# {xi: 14.741841222386679, lambda: 293.07678881583274, gamma: 9.719408902435962, delta: 2.4072423325045262}
# LAPLACE
# {'test_statistic': 14134070.257927354, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 14134070.257927354, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {mu: 20.263554240575, b: 1.7243727301874958}
# LEVY
# {'test_statistic': 11676.86184895241, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 11676.86184895241, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {mu: 15.625216085790067, c: 3.4958750922907385}
# LOGISTIC
# {'test_statistic': 6823674411.751041, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 6823674411.751041, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {mu: 20.263554240575, sigma: 1.3444879018617713}
# LOGLOGISTIC
# {'test_statistic': 2270239.4940347807, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 2270239.4940347807, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {alpha: 4.734329384129282, beta: 4.063784782820494}
# LOGLOGISTIC_3P
# {'test_statistic': 48.374382035113456, 'critical_value': 27.58711163827534, 'p-value': 7.525494575622016e-05, 'rejected': True}
# {testStatistic: 48.374382035113456, criticalValue: 27.58711163827534, pValue: 7.525494575622016e-05, rejected: true}
# {alpha: 4.734329384129282, beta: 4.063784782820494, loc: 15.066969941200574}
# MOYAL
# {'test_statistic': 94748.1689725433, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 94748.1689725433, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {mu: 18.868988305583994, sigma: 1.0977697749688284}
# XXX
# NC_F
# {'test_statistic': 900720276676.2782, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 900720276676.2782, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {lambda: 3848508.417250784, n1: 203321.40575243143, n2: 139.7162713691657}
# NON_CENTRAL_T_STUDENT
# {'test_statistic': 54.92496931017814, 'critical_value': 26.29622760486423, 'p-value': 3.6584424407681837e-06, 'rejected': True}
# {testStatistic: 54.92496931017814, criticalValue: 26.29622760486423, pValue: 3.6584424407681837e-06, rejected: true}
# {lambda: 3.1717414396172563, n: 5.25783278124999, loc: 15.646455597618083, scale: 1.2359004727228555}
# PERT
# {'test_statistic': 18398.133590817866, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 18398.133590817866, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {a: 13.119741191227535, b: 20.263554240575004, c: 65.19363605000001}
# RECIPROCAL
# {'test_statistic': 28577.482511062957, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 28577.482511062957, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {a: 15.6543061, b: 65.19263606}
# SEMICIRCULAR
# {'test_statistic': 82609.09472742137, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 82609.09472742137, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {loc: 20.263554240575, R: 44.939081809425}
# TRAPEZOIDAL
# {'test_statistic': 221742.12077124388, 'critical_value': 26.29622760486423, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 221742.12077124388, criticalValue: 26.29622760486423, pValue: 0.0, rejected: true}
# {a: 15.65330611, b: 39.803211760733774, c: 39.80295909018348, d: 65.19363605000001}
# TRIANGULAR
# {'test_statistic': 49617.52619847476, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 49617.52619847476, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {a: 15.65330611, b: 65.19363605000001, c: -20.056279438275013}
# T_STUDENT
# {'test_statistic': 22380517.218478035, 'critical_value': 30.14352720564616, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 22380517.218478035, criticalValue: 30.14352720564616, pValue: 0.0, rejected: true}
# {df: 2.4042917489350457}
# T_STUDENT_3P
# {'test_statistic': 653.7152002954026, 'critical_value': 27.58711163827534, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 653.7152002954026, criticalValue: 27.58711163827534, pValue: 0.0, rejected: true}
# {df: 4.220315844819295, loc: 19.97779318210356, scale: 1.6668704310524425}
# UNIFORM
# {'test_statistic': 57997.55062341523, 'critical_value': 28.869299430392623, 'p-value': 0.0, 'rejected': True}
# {testStatistic: 57997.55062341523, criticalValue: 28.869299430392623, pValue: 0.0, rejected: true}
# {a: 15.6543061, b: 65.19263606}

# %%
results = {k: v for k, v in sorted(results.items(), key=lambda item: item[1], reverse=True)}
results
# Out:
# {<distributions.alpha.ALPHA at 0x2c0cf9b6230>: 0.000570182816067355,
#  <distributions.loglogistic_3p.LOGLOGISTIC_3P at 0x2c0cfb6c790>: 7.525494575622016e-05,
#  <distributions.non_central_t_student.NON_CENTRAL_T_STUDENT at 0x2c0cfb6cc10>: 3.6584424407681837e-06,
#  <distributions.arcsine.ARCSINE at 0x2c0cf9a3f40>: 0.0,
#  <distributions.argus.ARGUS at 0x2c0cf9a3b50>: 0.0,
#  <distributions.beta_prime.BETA_PRIME at 0x2c0cf9a2ad0>: 0.0,
#  <distributions.beta_prime_4p.BETA_PRIME_4P at 0x2c0b71b7070>: 0.0,
#  <distributions.bradford.BRADFORD at 0x2c0cf9a2b90>: 0.0,
#  <distributions.burr.BURR at 0x2c0cfa60ca0>: 0.0,
#  <distributions.burr_4p.BURR_4P at 0x2c0cfa60df0>: 0.0,
#  <distributions.cauchy.CAUCHY at 0x2c0cfa60e80>: 0.0,
#  <distributions.chi_square.CHI_SQUARE at 0x2c0cfa60d00>: 0.0,
#  <distributions.chi_square_3p.CHI_SQUARE_3P at 0x2c0cfa61000>: 0.0,
#  <distributions.dagum.DAGUM at 0x2c0cfa60fd0>: 0.0,
#  <distributions.exponential.EXPONENTIAL at 0x2c0cfa61390>: 0.0,
#  <distributions.exponential_2p.EXPONENTIAL_2P at 0x2c0cf9a3d60>: 0.0,
#  <distributions.f.F at 0x2c0cfa60610>: 0.0,
#  <distributions.fatigue_life.FATIGUE_LIFE at 0x2c0cfa61d50>: 0.0,
#  <distributions.frechet.FRECHET at 0x2c0cfa61d20>: 0.0,
#  <distributions.f_4p.F_4P at 0x2c0cfa61a80>: 0.0,
#  <distributions.generalized_extreme_value.GENERALIZED_EXTREME_VALUE at 0x2c0cfa61ab0>: 0.0,
#  <distributions.generalized_logistic.GENERALIZED_LOGISTIC at 0x2c0cfa61870>: 0.0,
#  <distributions.generalized_normal.GENERALIZED_NORMAL at 0x2c0cfa62230>: 0.0,
#  <distributions.generalized_pareto.GENERALIZED_PARETO at 0x2c0cfb6b6d0>: 0.0,
#  <distributions.gibrat.GIBRAT at 0x2c0cfa62260>: 0.0,
#  <distributions.gumbel_right.GUMBEL_RIGHT at 0x2c0cfa617e0>: 0.0,
#  <distributions.hyperbolic_secant.HYPERBOLIC_SECANT at 0x2c0cfb6c550>: 0.0,
#  <distributions.inverse_gamma.INVERSE_GAMMA at 0x2c0cfa62200>: 0.0,
#  <distributions.inverse_gamma_3p.INVERSE_GAMMA_3P at 0x2c0cfb6b610>: 0.0,
#  <distributions.johnson_sb.JOHNSON_SB at 0x2c0cfa61bd0>: 0.0,
#  <distributions.laplace.LAPLACE at 0x2c0cfb6c700>: 0.0,
#  <distributions.levy.LEVY at 0x2c0cfb6ccd0>: 0.0,
#  <distributions.logistic.LOGISTIC at 0x2c0cfb6cb80>: 0.0,
#  <distributions.loglogistic.LOGLOGISTIC at 0x2c0cfb6c760>: 0.0,
#  <distributions.moyal.MOYAL at 0x2c0cfb6cca0>: 0.0,
#  <distributions.non_central_f.NC_F at 0x2c0cf9a2ef0>: 0.0,
#  <distributions.pert.PERT at 0x2c0cfb6ca30>: 0.0,
#  <distributions.reciprocal.RECIPROCAL at 0x2c0cfb6ce20>: 0.0,
#  <distributions.semicircular.SEMICIRCULAR at 0x2c0cfb6ca00>: 0.0,
#  <distributions.trapezoidal.TRAPEZOIDAL at 0x2c0cfb6cd60>: 0.0,
#  <distributions.triangular.TRIANGULAR at 0x2c0cfb6cbb0>: 0.0,
#  <distributions.t_student.T_STUDENT at 0x2c0cfb6cf70>: 0.0,
#  <distributions.t_student_3p.T_STUDENT_3P at 0x2c0b725aad0>: 0.0,
#  <distributions.uniform.UNIFORM at 0x2c09ee80c10>: 0.0}

# %%
## Histogram of data
plt.figure(figsize=(8, 4))
plt.hist(data, bins=num_bins, density=True, ec="white", color=(168 / 235, 12 / 235, 12 / 235))
plt.title("HISTOGRAM")
plt.xlabel("Values")
plt.ylabel("Frequencies")

ll = min(data)
ul = max(data)
for distribution, sse in list(results.items())[:3]:
    if distribution.__class__.__name__ in [
        "LEVY",
        "CAUCHY",
        "FRECHET",
        "GENERALIZED_PARETO",
    ]:
        ll = min(data) - 10
        ul = max(data) + 10
    x_plot = numpy.linspace(ll, ul, 1000)
    y_plot = [distribution.pdf(x) for x in x_plot]
    label_d = distribution.__class__.__name__ + ": " + str(round(sse, 4))
    color_d = [random.uniform(0, 1), random.uniform(0, 1), random.uniform(0, 1)]
    plt.plot(x_plot, y_plot, label=label_d, color=color_d)

plt.legend(title="NOT REJECTED DISTRIBUTIONS", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()
