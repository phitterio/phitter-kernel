# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/phitterio/phitter-kernel/blob/main/examples/fit_specefic_distribution.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TUTORIAL: FIT SPECIFIC DISTRIBUTIONS**

# %%
import os
import sys

# %%
if os.getenv("COLAB_RELEASE_TAG"):
   # !pip install phitter --quiet
else:
   sys.path.append("../")

# %%
import phitter

# %% [markdown]
# **Initializes distribution providing a dict with patameters specified in documentation**

# %%
distribution = phitter.continuous.BETA({"alpha": 5, "beta": 2, "A": 100, "B": 1000})
data = distribution.sample(10000)

# %% [markdown]
# **Initialize the PHITTER model**

# %%
phitter_cont = phitter.PHITTER(data=data, distributions_to_fit=["beta"])
phitter_cont.fit()

# %% [markdown]
# **Get distrbutions sorted by sse**

# %%
phitter_cont.df_sorted_distributions_sse
# Out:
#   distribution passed           sse  \
#
# 0         beta      ✅  1.797840e-07
#
#                                       parameters     chi_square  \
#                                                  test_statistic
# 0  alpha: 4.389, beta: 1.719, A: 135.9, B: 984.3      67.008189
#
#                                         kolmogorov_smirnov                 \
#   critical_value       p_value rejected     test_statistic critical_value
# 0       24.99579  1.515241e-08     True            0.01033       0.013564
#
#                      anderson_darling
#     p_value rejected   test_statistic critical_value p_value rejected
# 0  0.234719    False             None           None    None     None

# %% [markdown]
# **Plot a histogram of the dataset values to visualize the distribution**

# %%
phitter_cont.plot_histogram_distributions()
